# %%
import pandas as pd

df = pd.read_csv (r'/home/janislley/Downloads/vanessa/TCC_results/Questionario TCC.csv')
print (df)
# Out:
#              Carimbo de data/hora  \
# 0     2021/03/17 9:40:48 PM GMT-4
# 1     2021/03/21 8:00:30 PM GMT-4
# 2     2021/03/21 8:04:18 PM GMT-4
# 3     2021/03/21 8:15:21 PM GMT-4
# 4     2021/03/21 8:24:43 PM GMT-4
# ..                            ...
# 103  2021/04/03 10:02:32 AM GMT-4
# 104  2021/04/04 10:12:54 AM GMT-4
# 105   2021/04/07 8:48:57 PM GMT-4
# 106  2021/04/09 11:30:08 PM GMT-4
# 107   2021/04/29 4:50:38 PM GMT-4
#
#                                            Declaro que  Qual a sua idade?  \
# 0    Li o termo de consentimento e aceito fazer par...                 55
# 1    Li o termo de consentimento e aceito fazer par...                 47
# 2    Li o termo de consentimento e aceito fazer par...                 56
# 3    Li o termo de consentimento e aceito fazer par...                 52
# 4    Li o termo de consentimento e aceito fazer par...                 36
# ..                                                 ...                ...
# ...

# %%
import os
import numpy as np
from matplotlib import pyplot as plt


grupos = ["""Calores ou calafrios""", 
          """Transpiração não devido ao calor""", 
          """Dificuldade de engolir "bola na garganta" """,
          """Boca seca""", 
          """Respiração superficial""", 
          """Tremores/Espasmos musculares""", 
          """Evitar lugares onde posso ficar ansioso""",
          """Urinação frequente""",
          """Sente-se incapaz de lidar com dificuldades""",
          """Tonteira/vertigem""",
          """Náusea ou problemas estomacais""",
          """Batimento cardíaco acelerado""",
          """Facilmente assustado""",
          """Pensamentos frequentes de que algo terrível irá acontecer""",
          """Pensamentos frequentes de perigo""",
          """Pressão ou Inquietação na cabeça""",
          """Cansaço fácil""",
          """Tensão""",
          """Dificuldade de concentração""",
          """Nervosismo""",
          """Inquietação""",
          """Tensão muscular""",
          """Irritabilidade""",
          """Preocupação frequente"""]
valores = [9, 12, 13, 16, 17, 18, 20, 21, 25, 27, 27, 32, 32, 33, 35, 40, 53, 57, 58, 58, 61, 62, 71, 85]

plt.figure(figsize=(7,10))
plt.barh(grupos, valores, color="black")
plt.xlabel('Quantidade de manifestações.')

plt.show()

plt.savefig('books_read.png')
